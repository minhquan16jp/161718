# %% [markdown]
# <a href="https://colab.research.google.com/github/minhquan16jp/161718/blob/main/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="50000")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='50000', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
import warnings
warnings.filterwarnings("ignore")
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# Total files: 32
# Total files: 3
# Copy at Folder 1. N2 12-2010 Starting
# [1. N2 12-2010.pdf] copied. Size 1.78 MB. Speed 1.52 MB/s
# [1. N2-12.2010(script).pdf] copied. Size 2.69 MB. Speed 2.85 MB/s
# [1. Nghe N2 12-2010.mp3] copied. Size 27.04 MB. Speed 26.96 MB/s
# Copy at Folder 1. N2 12-2010 Ending
# Total files: 3
# Copy at Folder 1. N2 7-2010 Starting
# [1. N2 7-2010(script).pdf] copied. Size 2.48 MB. Speed 2.28 MB/s
# [1. N2 7-2010.pdf] copied. Size 1.89 MB. Speed 1.94 MB/s
# [1. Nghe N2 7-2010.mp3] copied. Size 26.56 MB. Speed 30.01 MB/s
# Copy at Folder 1. N2 7-2010 Ending
# Total files: 3
# Copy at Folder 10. N2 12-2019 Starting
# [10. N2 12-2019(script).pdf] copied. Size 3.02 MB. Speed 2.86 MB/s
# [10. N2 12-2019.pdf] copied. Size 2.15 MB. Speed 2.29 MB/s
# [10. Nghe N2 12-2019.mp3] copied. Size 37.67 MB. Speed 41.39 MB/s
# Copy at Folder 10. N2 12-2019 Ending
# Total files: 3
# Copy at Folder 10. N2 7-2019 Starting
# [10. N2 7-2019(script).pdf] copied. Size 2.79 MB. Speed 2.62 MB/s
# [10. N2 7-2019.pdf] copied. Size 2.32 MB. Speed 2.43 MB/s
# [10. Nghe N2 7-2019.mp3] copied. Size 42.52 MB. Speed 50.77 MB/s
# Copy at Folder 10. N2 7-2019 Ending
# Total files: 3
# Copy at Folder 11. N2 12-2020 Starting
# [11. N2 12-2020(script).pdf] copied. Size 2.85 MB. Speed 2.00 MB/s
# [11. N2 12-2020.pdf] copied. Size 2.28 MB. Speed 2.50 MB/s
# [11.Nghe N2 12-2020.mp3] copied. Size 35.06 MB. Speed 41.81 MB/s
# Copy at Folder 11. N2 12-2020 Ending
# Total files: 3
# Copy at Folder 12. N2 12-2021 Starting
# [12. N2 12-2021(script).pdf] copied. Size 2.56 MB. Speed 2.30 MB/s
# [12. N2 12-2021.pdf] copied. Size 2.16 MB. Speed 2.51 MB/s
# [12. Nghe N2 12-2021.mp3] copied. Size 39.72 MB. Speed 47.56 MB/s
# Copy at Folder 12. N2 12-2021 Ending
# Total files: 3
# Copy at Folder 12. N2 7-2021 Starting
# [12. N2 07-2021(script).pdf] copied. Size 2.94 MB. Speed 2.28 MB/s
# [12. N2 7-2021.pdf] copied. Size 2.15 MB. Speed 2.49 MB/s
# [12. Nghe N2 7-2021.mp3] copied. Size 39.66 MB. Speed 39.78 MB/s
# Copy at Folder 12. N2 7-2021 Ending
# Total files: 3
# Copy at Folder 13. N2 12-2022 Starting
# [13. N2 12-2022(script).pdf] copied. Size 2.44 MB. Speed 1.81 MB/s
# [13. N2 12-2022.pdf] copied. Size 2.19 MB. Speed 2.48 MB/s
# [13. Nghe N2 T12-2022.mp3] copied. Size 62.03 MB. Speed 63.26 MB/s
# Copy at Folder 13. N2 12-2022 Ending
# Total files: 4
# Copy at Folder 13. N2 7-2022 Starting
# [13. N2 07-2022(script).pdf] copied. Size 2.80 MB. Speed 2.33 MB/s
# [13. N2 7-2022_update 260601.pdf] copied. Size 2.23 MB. Speed 2.84 MB/s
# [13. Nghe N2 T7-2022.mp3] copied. Size 39.94 MB. Speed 38.35 MB/s
# [13. Nghe N2 T7-2022.rar] copied. Size 26.36 MB. Speed 30.42 MB/s
# Copy at Folder 13. N2 7-2022 Ending
# Total files: 3
# Copy at Folder 14. N2 12-2023 Starting
# [14. Nghe N2 T12-2023.mp3] copied. Size 44.84 MB. Speed 17.65 MB/s
# [14. script N2 12-2023.pdf] copied. Size 1.07 MB. Speed 1.07 MB/s
# [14.N2 12-2023.pdf] copied. Size 1.60 MB. Speed 1.63 MB/s
# Copy at Folder 14. N2 12-2023 Ending
# Total files: 3
# Copy at Folder 14. N2 7-2023 Starting
# [14. N2 7-2023 (script).pdf] copied. Size 2.72 MB. Speed 1.80 MB/s
# [14. N2 7-2023.pdf] copied. Size 2.49 MB. Speed 2.57 MB/s
# [File nghe N2 7-2023.mp3] copied. Size 41.42 MB. Speed 44.63 MB/s
# Copy at Folder 14. N2 7-2023 Ending
# Total files: 3
# Copy at Folder 15. N2 12-2024 Starting
# [15. N2 12.2024 (update 260606).pdf] copied. Size 1.92 MB. Speed 1.69 MB/s
# [15. script N2 12.2024.pdf] copied. Size 0.98 MB. Speed 1.18 MB/s
# [Nghe N2 T12-2024.mp3] copied. Size 68.43 MB. Speed 80.64 MB/s
# Copy at Folder 15. N2 12-2024 Ending
# Total files: 3
# Copy at Folder 15. N2 7-2024 Starting
# [15. N2 7.2024.pdf] copied. Size 1.67 MB. Speed 1.48 MB/s
# [Nghe N2 T7-2024.mp3] copied. Size 44.07 MB. Speed 35.83 MB/s
# [script N2 7.2024.pdf] copied. Size 0.97 MB. Speed 1.15 MB/s
# Copy at Folder 15. N2 7-2024 Ending
# Total files: 3
# Copy at Folder 16. N2 7-2025 Starting
# [16. N2 07-2025.pdf] copied. Size 1.77 MB. Speed 1.90 MB/s
# [16. N2-7.2025 (script).pdf] copied. Size 2.41 MB. Speed 2.52 MB/s
# [Nghe N2 T7-2025.mp3] copied. Size 38.61 MB. Speed 15.76 MB/s
# Copy at Folder 16. N2 7-2025 Ending
# Total files: 4
# Copy at Folder 17.N2 12-2025 Starting
# [17 (script) N2 12-2025 _260410.pdf] copied. Size 2.81 MB. Speed 2.49 MB/s
# [17.N2 12-2025 _260603.pdf] copied. Size 2.01 MB. Speed 2.31 MB/s
# [JLPT N2 12.2025 Choukai.mp3] copied. Size 42.72 MB. Speed 46.48 MB/s
# [JLPT N2 12.2025 Choukai.rar] copied. Size 33.63 MB. Speed 37.56 MB/s
# Copy at Folder 17.N2 12-2025 Ending
# Total files: 3
# Copy at Folder 2. N2 12-2011 Starting
# [2. N2 12-2011(script).pdf] copied. Size 2.69 MB. Speed 2.35 MB/s
# [2. N2 12-2011.pdf] copied. Size 1.79 MB. Speed 2.11 MB/s
# [2. Nghe N2-12-2011.mp3] copied. Size 44.12 MB. Speed 43.45 MB/s
# Copy at Folder 2. N2 12-2011 Ending
# Total files: 3
# Copy at Folder 2. N2 7-2011 Starting
# [2. N2 7-2011(script).pdf] copied. Size 2.57 MB. Speed 2.04 MB/s
# [2. N2 7-2011.pdf] copied. Size 1.72 MB. Speed 1.93 MB/s
# [2. Nghe N2 7-2011.mp3] copied. Size 21.01 MB. Speed 25.17 MB/s
# Copy at Folder 2. N2 7-2011 Ending
# Total files: 3
# Copy at Folder 3. N2 12-2012 Starting
# [3. N2 12-2012 (script).pdf] copied. Size 2.81 MB. Speed 3.43 MB/s
# [3. N2 12-2012.pdf] copied. Size 1.71 MB. Speed 1.64 MB/s
# [3. Nghe N2 12-2012.mp3] copied. Size 19.66 MB. Speed 21.99 MB/s
# Copy at Folder 3. N2 12-2012 Ending
# Total files: 3
# Copy at Folder 3. N2 7-2012 Starting
# [3. N2 7-2012(script).pdf] copied. Size 2.51 MB. Speed 3.16 MB/s
# [3. N2 7-2012.pdf] copied. Size 1.99 MB. Speed 2.22 MB/s
# [3. Nghe N2 7-2012.mp3] copied. Size 17.33 MB. Speed 19.15 MB/s
# Copy at Folder 3. N2 7-2012 Ending
# Total files: 3
# Copy at Folder 4. N2 12-2013 Starting
# [4. N2 12-2013 (script).pdf] copied. Size 2.76 MB. Speed 2.50 MB/s
# [4. N2 12-2013.pdf] copied. Size 1.78 MB. Speed 1.90 MB/s
# [4. Nghe N2 12-2013.mp3] copied. Size 22.29 MB. Speed 24.76 MB/s
# Copy at Folder 4. N2 12-2013 Ending
# Total files: 3
# Copy at Folder 4. N2 7-2013 Starting
# [4. N2 7-2013(script).pdf] copied. Size 2.64 MB. Speed 2.45 MB/s
# [4. N2 7-2013.pdf] copied. Size 1.98 MB. Speed 2.22 MB/s
# [4. Nghe N2 7-2013.mp3] copied. Size 19.74 MB. Speed 18.81 MB/s
# Copy at Folder 4. N2 7-2013 Ending
# Total files: 3
# Copy at Folder 5. N2 12-2014 Starting
# [5. N2 12-2014(script).pdf] copied. Size 2.87 MB. Speed 2.67 MB/s
# [5. N2 12-2014.pdf] copied. Size 1.88 MB. Speed 2.27 MB/s
# [5. Nghe N2 12-2014.mp3] copied. Size 23.49 MB. Speed 26.43 MB/s
# Copy at Folder 5. N2 12-2014 Ending
# Total files: 3
# Copy at Folder 5. N2 7-2014 Starting
# [5. N2 7-2014(script).pdf] copied. Size 2.66 MB. Speed 3.16 MB/s
# [5. N2 7-2014.pdf] copied. Size 1.95 MB. Speed 2.23 MB/s
# [5. Nghe N2 7-2014.mp3] copied. Size 23.62 MB. Speed 26.34 MB/s
# Copy at Folder 5. N2 7-2014 Ending
# Total files: 3
# Copy at Folder 6. N2 12-2015 Starting
# [6. N2 12-2015(script).pdf] copied. Size 3.05 MB. Speed 3.02 MB/s
# [6. N2 12-2015.pdf] copied. Size 2.06 MB. Speed 1.90 MB/s
# [6. Nghe N2 12-2015.mp3] copied. Size 29.12 MB. Speed 32.79 MB/s
# Copy at Folder 6. N2 12-2015 Ending
# Total files: 3
# Copy at Folder 6. N2 7-2015 Starting
# [6. N2 7-2015(script).pdf] copied. Size 2.87 MB. Speed 2.55 MB/s
# [6. N2 7-2015.pdf] copied. Size 1.95 MB. Speed 2.31 MB/s
# [6. Nghe N2 7-2015.mp3] copied. Size 23.72 MB. Speed 23.57 MB/s
# Copy at Folder 6. N2 7-2015 Ending
# Total files: 3
# Copy at Folder 7. N2 12-2016 Starting
# [7. N2 12 2016.pdf] copied. Size 2.07 MB. Speed 2.01 MB/s
# [7. N2 12-2016(script).pdf] copied. Size 3.20 MB. Speed 3.68 MB/s
# [7. Nghe N2 12-2016.mp3] copied. Size 24.34 MB. Speed 27.86 MB/s
# Copy at Folder 7. N2 12-2016 Ending
# Total files: 3
# Copy at Folder 7. N2 7-2016 Starting
# [7. N2 7-2016(script).pdf] copied. Size 2.85 MB. Speed 2.53 MB/s
# [7. N2 7-2016.pdf] copied. Size 2.08 MB. Speed 2.30 MB/s
# [7. Nghe N2 7-2016.mp3] copied. Size 22.43 MB. Speed 23.58 MB/s
# Copy at Folder 7. N2 7-2016 Ending
# Total files: 3
# Copy at Folder 8. N2 12-2017 Starting
# [8. N2 12 2017.pdf] copied. Size 1.81 MB. Speed 1.68 MB/s
# [8. Nghe N2 12-2017.mp3] copied. Size 46.08 MB. Speed 23.81 MB/s
# [8.N2-12.2017(script).pdf] copied. Size 3.11 MB. Speed 3.43 MB/s
# Copy at Folder 8. N2 12-2017 Ending
# Total files: 3
# Copy at Folder 8. N2 7-2017 Starting
# [8. N2 7-2017(script).pdf] copied. Size 2.92 MB. Speed 2.54 MB/s
# [8. N2 7-2017.pdf] copied. Size 2.31 MB. Speed 2.38 MB/s
# [8. Nghe N2 T7 2017.mp3] copied. Size 43.68 MB. Speed 48.87 MB/s
# Copy at Folder 8. N2 7-2017 Ending
# Total files: 3
# Copy at Folder 9. N2 12-2018 Starting
# [9. N2 12-2018(script).pdf] copied. Size 3.29 MB. Speed 2.72 MB/s
# [9. N2 12-2018.pdf] copied. Size 2.17 MB. Speed 2.68 MB/s
# [9. Nghe N2 12-2018.mp3] copied. Size 36.20 MB. Speed 39.16 MB/s
# Copy at Folder 9. N2 12-2018 Ending
# Total files: 3
# Copy at Folder 9. N2 7-2018 Starting
# [9. N2 7-2018(script).pdf] copied. Size 3.06 MB. Speed 2.80 MB/s
# [9. N2 7-2018.pdf] copied. Size 2.32 MB. Speed 1.23 MB/s
# [9. Nghe N2 7-2018.mp3] copied. Size 59.13 MB. Speed 66.09 MB/s
# Copy at Folder 9. N2 7-2018 Ending
# [ĐÁP ÁN JLPT N2 (update 10.4.2026).pdf] copied. Size 2.16 MB. Speed 1.37 MB/s
# Done. Total Size 1.28 GB. Total Time 122 s. SpeedMB 10.67 MB/s
