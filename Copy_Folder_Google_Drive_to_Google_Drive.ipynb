# %% [markdown]
# <a href="https://colab.research.google.com/github/minhquan16jp/161718/blob/main/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="700")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='700', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# Total files: 3
# Total files: 29
# Copy at Folder Bài giảng Starting
# Total files: 12
# Copy at Folder 01. Bảng chữ cái Hiragana Starting
# [Bản sao của 01.Giới thiệu bảng chữ cái trong tiếng nhật - học tiếng nhật online dungmori.com.mp4.mp4_2.mp4] copied. Size 35.80 MB. Speed 18.13 MB/s
# [Bản sao của 02. Bảng chữ cái tiếng nhật Hiragana A,I, U, E, O - Tiếng nhật online cho người mới bắt đầu.mp4.mp4_2.mp4] copied. Size 78.35 MB. Speed 46.33 MB/s
# [Bản sao của 03. Hiragana Ta,Chi, Tsu, Te, To.mp4.mp4_2.mp4] copied. Size 149.60 MB. Speed 72.24 MB/s
# [Bản sao của 04.Hiragana Ga,Gi,Gu,Ge,Go.mp4.mp4_2.mp4] copied. Size 68.85 MB. Speed 38.03 MB/s
# [Bản sao của 05. Hiragana Kya,Kyu,Kyo,Gya,Gyu,Gyo.mp4.mp4_2.mp4] copied. Size 44.16 MB. Speed 24.08 MB/s
# [Bản sao của 06.Cách đọc trong tiếng nhật.mp4.mp4_2.mp4] copied. Size 44.89 MB. Speed 21.14 MB/s
# [Bản sao của 07.Cách phân biệt đơn giản -Từ có trường âm và không có trường âm..mp4.mp4_2.mp4] copied. Size 71.19 MB. Speed 29.43 MB/s
# [Bản sao của 08.Sửa lỗi phát âm つ、ふ、ひ、しゃ、しゅ、しょ、じゃ、じゅ、じょ.mp4.mp4_2.mp4] copied. Size 104.58 MB. Speed 42.87 MB/s
# [Bản sao của 09.Sửa phát âm - chia sẻ việc luyện phát âm của cô Hà.mp4.mp4_2.mp4] copied. Size 67.36 MB. Speed 29.04 MB/s
# [Bản sao của 10. học số đếm cùng với thầy shimakawa.mp4.mp4_2.mp4] copied. Size 39.24 MB. Speed 16.49 MB/s
# [Bản sao của 11.Học số đếm giỏi hơn bằng cách đếm tiền Việt Nam.mp4.mp4_2.mp4] copied. Size 75.19 MB. Speed 32.23 MB/s
# [Bản sao của 12. Các câu chào hỏi thường ngày.mp4.mp4_2.mp4] copied. Size 72.77 MB. Speed 33.37 MB/s
# Copy at Folder 01. Bảng chữ cái Hiragana Ending
# Total files: 1
# Copy at Folder 02.Bảng chữ cái Katakana Starting
# [Bản sao của Bảng chữ cái Katakana - 1.mp4_2.mp4] copied. Size 180.11 MB. Speed 82.08 MB/s
# Copy at Folder 02.Bảng chữ cái Katakana Ending
# Total files: 6
# Copy at Folder 03.Các bài học thú vị Starting
# [Bản sao của 01.Bài 1TIẾNG NHẬT DỄ thế này cơ mà.mp4.mp4] copied. Size 16.55 MB. Speed 8.60 MB/s
# [Bản sao của 02.Số đếm từ 1 đến 10.mp4_2.mp4] copied. Size 56.80 MB. Speed 26.45 MB/s
# [Bản sao của 03.Bài 2 Thầy giáo say mê dạy tiếng nhật nên bị LỘ HÀNG.mp4_2.mp4] copied. Size 62.06 MB. Speed 37.84 MB/s
# [Bản sao của 04.Bài 3 Cách nhớ từ vựng siêu cấp - Từ vựng về động vật..mp4_2.mp4] copied. Size 59.28 MB. Speed 33.57 MB/s
# [Bản sao của 05.Bài 4 Từ vựng liên quan đến cơ thể - siêu thú vị.mp4_2.mp4] copied. Size 102.60 MB. Speed 60.80 MB/s
# [Bản sao của 06.Bài 5 Học tiếng nhật cùng chim sẻ đi nắng - Game thủ AOE.mp4] copied. Size 95.23 MB. Speed 56.42 MB/s
# Copy at Folder 03.Các bài học thú vị Ending
# Total files: 8
# Copy at Folder 04.Tài liệu học tập Starting
# [Bản sao của 1. Sách Bảng chữ cái.pdf] copied. Size 5.57 MB. Speed 2.85 MB/s
# [Bản sao của 2. Đáp án _ scrift sách Minna.pdf] copied. Size 2.41 MB. Speed 1.20 MB/s
# [Bản sao của 3. Sách Giáo khoa.pdf] copied. Size 20.49 MB. Speed 11.90 MB/s
# [Bản sao của 5. Tài liệu Ngữ pháp trong khóa học.pdf] copied. Size 15.09 MB. Speed 7.78 MB/s
# [Bản sao của 6. Sách Từ vựng và giải thích ngữ pháp.pdf] copied. Size 5.50 MB. Speed 2.02 MB/s
# [Bản sao của 7. Sách Đọc hiểu N5 ( bản mới ).pdf] copied. Size 5.34 MB. Speed 1.62 MB/s
# [Bản sao của 8. Sách Kanji.pdf] copied. Size 2.78 MB. Speed 0.51 MB/s
# Total files: 63
# Copy at Folder File nghe minnano nihongo I Starting
# [Bản sao của 01 01.mp3] copied. Size 0.37 MB. Speed 0.24 MB/s
# [Bản sao của 02 02.mp3] copied. Size 0.48 MB. Speed 0.21 MB/s
# [Bản sao của 03 03.mp3] copied. Size 0.46 MB. Speed 0.17 MB/s
# [Bản sao của 05 05.mp3] copied. Size 0.56 MB. Speed 0.32 MB/s
# [Bản sao của 06 06.mp3] copied. Size 0.45 MB. Speed 0.11 MB/s
# [Bản sao của 07 07.mp3] copied. Size 0.55 MB. Speed 0.22 MB/s
# [Bản sao của 08 08.mp3] copied. Size 0.70 MB. Speed 0.17 MB/s
# [Bản sao của 09 09.mp3] copied. Size 0.58 MB. Speed 0.33 MB/s
# [Bản sao của 10 10.mp3] copied. Size 0.45 MB. Speed 0.22 MB/s
# [Bản sao của 12 12.mp3] copied. Size 0.61 MB. Speed 0.44 MB/s
# [Bản sao của 13 13.mp3] copied. Size 0.47 MB. Speed 0.25 MB/s
# [Bản sao của 14 14.mp3] copied. Size 0.40 MB. Speed 0.19 MB/s
# [Bản sao của 15 15.mp3] copied. Size 0.94 MB. Speed 0.58 MB/s
# [Bản sao của 16 16.mp3] copied. Size 0.88 MB. Speed 0.53 MB/s
# [Bản sao của 17 17.mp3] copied. Size 0.76 MB. Speed 0.40 MB/s
# [Bản sao của 18 18.mp3] copied. Size 0.46 MB. Speed 0.25 MB/s
# [Bản sao của 19 19.mp3] copied. Size 0.37 MB. Speed 0.20 MB/s
# [Bản sao của 20 20.mp3] copied. Size 0.84 MB. Speed 0.41 MB/s
# [Bản sao của 21 21.mp3] copied. Size 0.43 MB. Speed 0.18 MB/s
# [Bản sao của 22 22.mp3] copied. Size 0.46 MB. Speed 0.26 MB/s
# [Bản sao của 24 24.mp3] copied. Size 0.70 MB. Speed 0.43 MB/s
# [Bản sao của 25 25.mp3] copied. Size 0.51 MB. Speed 0.24 MB/s
# [Bản sao của 26 26.mp3] copied. Size 0.35 MB. Speed 0.22 MB/s
# [Bản sao của 27 27.mp3] copied. Size 0.87 MB. Speed 0.49 MB/s
# [Bản sao của 28 28.mp3] copied. Size 0.64 MB. Speed 0.37 MB/s
# [Bản sao của 29 29.mp3] copied. Size 0.45 MB. Speed 0.29 MB/s
# [Bản sao của 30 30.mp3] copied. Size 0.35 MB. Speed 0.22 MB/s
# [Bản sao của 31 31.mp3] copied. Size 0.92 MB. Speed 0.58 MB/s
# [Bản sao của 32 32.mp3] copied. Size 0.73 MB. Speed 0.15 MB/s
# [Bản sao của 33 33.mp3] copied. Size 0.46 MB. Speed 0.26 MB/s
# [Bản sao của 35 35.mp3] copied. Size 0.60 MB. Speed 0.36 MB/s
# [Bản sao của 36 36.mp3] copied. Size 0.47 MB. Speed 0.24 MB/s
# [Bản sao của 37 37.mp3] copied. Size 0.80 MB. Speed 0.51 MB/s
# [Bản sao của 38 38.mp3] copied. Size 0.66 MB. Speed 0.31 MB/s
# [Bản sao của 39 39.mp3] copied. Size 0.70 MB. Speed 0.43 MB/s
# [Bản sao của 40 40.mp3] copied. Size 0.51 MB. Speed 0.25 MB/s
# [Bản sao của 41 41.mp3] copied. Size 0.32 MB. Speed 0.17 MB/s
# [Bản sao của 42 42.mp3] copied. Size 0.92 MB. Speed 0.45 MB/s
# [Bản sao của 43 43.mp3] copied. Size 0.55 MB. Speed 0.33 MB/s
# [Bản sao của 44 44.mp3] copied. Size 0.49 MB. Speed 0.26 MB/s
# [Bản sao của 46 46.mp3] copied. Size 0.89 MB. Speed 0.52 MB/s
# [Bản sao của 47 47.mp3] copied. Size 0.51 MB. Speed 0.26 MB/s
# [Bản sao của 49 49.mp3] copied. Size 0.81 MB. Speed 0.47 MB/s
# [Bản sao của 53 53.mp3] copied. Size 0.56 MB. Speed 0.33 MB/s
# [Bản sao của 56 56.mp3] copied. Size 0.64 MB. Speed 0.40 MB/s
# [Bản sao của 60 60.mp3] copied. Size 0.63 MB. Speed 0.35 MB/s
# [Bản sao của 63 63.mp3] copied. Size 0.56 MB. Speed 0.29 MB/s
# [Bản sao của 64 64.mp3] copied. Size 0.49 MB. Speed 0.33 MB/s
# [Bản sao của 66 66.mp3] copied. Size 0.72 MB. Speed 0.33 MB/s
# [Bản sao của 67 67.mp3] copied. Size 0.40 MB. Speed 0.23 MB/s
# [Bản sao của 69 69.mp3] copied. Size 0.49 MB. Speed 0.31 MB/s
# [Bản sao của 70 70.mp3] copied. Size 0.46 MB. Speed 0.31 MB/s
# [Bản sao của 72 72.mp3] copied. Size 0.77 MB. Speed 0.34 MB/s
# [Bản sao của 73 73.mp3] copied. Size 0.51 MB. Speed 0.32 MB/s
# [Bản sao của 75 75.mp3] copied. Size 0.66 MB. Speed 0.42 MB/s
# [Bản sao của 76 76.mp3] copied. Size 0.52 MB. Speed 0.32 MB/s
# [Bản sao của 78 78.mp3] copied. Size 0.73 MB. Speed 0.47 MB/s
# [Bản sao của 79 79.mp3] copied. Size 0.51 MB. Speed 0.26 MB/s
# [Bản sao của 80 80.mp3] copied. Size 0.58 MB. Speed 0.35 MB/s
# [Bản sao của 82 82.mp3] copied. Size 0.59 MB. Speed 0.26 MB/s
# [Bản sao của 83 83.mp3] copied. Size 0.59 MB. Speed 0.27 MB/s
# [Bản sao của 85 85.mp3] copied. Size 0.65 MB. Speed 0.33 MB/s
# [Bản sao của 86 86.mp3] copied. Size 0.53 MB. Speed 0.29 MB/s
# Copy at Folder File nghe minnano nihongo I Ending
# Copy at Folder 04.Tài liệu học tập Ending
# Total files: 6
# Copy at Folder Bài 01. Chào hỏi giới thiệu bản thân Starting
# [Bản sao của 01.Từ vựng.mp4] copied. Size 11.68 MB. Speed 6.52 MB/s
# [Bản sao của 02.Ngữ pháp.mp4_2.mp4] copied. Size 123.53 MB. Speed 63.06 MB/s
# [Bản sao của 04.Nâng cao mina 1.mp4_2.mp4] copied. Size 112.25 MB. Speed 72.25 MB/s
# [Bản sao của 05.Hội thoại 1.mp4_2.mp4] copied. Size 23.23 MB. Speed 12.87 MB/s
# [Bản sao của 06.Nghe hiểu.mp4_2.mp4] copied. Size 7.51 MB. Speed 3.85 MB/s
# Total files: 4
# Copy at Folder Tài liệu Starting
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.34 MB. Speed 0.19 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.30 MB. Speed 0.15 MB/s
# [Bản sao của 05. Hội thoại 1.pdf] copied. Size 0.54 MB. Speed 0.27 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.53 MB. Speed 0.40 MB/s
# Copy at Folder Tài liệu Ending
# Copy at Folder Bài 01. Chào hỏi giới thiệu bản thân Ending
# Total files: 5
# Copy at Folder Bài 02. Đây là cái gì Starting
# [Bản sao của 01. Từ vựng.mp4_2.mp4] copied. Size 12.97 MB. Speed 7.26 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2.mp4] copied. Size 54.77 MB. Speed 29.63 MB/s
# [Bản sao của 04. Nâng cao Mina 2, 3.mp4_2.mp4] copied. Size 19.71 MB. Speed 11.43 MB/s
# [Bản sao của 05. Hội thoại 2.mp4_2.mp4] copied. Size 2.36 MB. Speed 1.25 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2.mp4] copied. Size 5.93 MB. Speed 3.25 MB/s
# Copy at Folder Bài 02. Đây là cái gì Ending
# Total files: 4
# Copy at Folder Bài 03. Đây là trường học của tôi Starting
# [Bản sao của 01. Từ vựng.mp4_2_2.mp4] copied. Size 6.01 MB. Speed 3.36 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2_2.mp4] copied. Size 32.78 MB. Speed 21.06 MB/s
# [Bản sao của 04. Nâng cao Mina 2, 3.mp4_2_2.mp4] copied. Size 19.70 MB. Speed 10.97 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2_2.mp4] copied. Size 6.65 MB. Speed 3.76 MB/s
# Copy at Folder Bài 03. Đây là trường học của tôi Ending
# Total files: 4
# Copy at Folder Bài 04. Bây giờ là mấy giờ Starting
# [Bản sao của 02. Khóa học N5 - Ngữ pháp.mp4] copied. Size 228.74 MB. Speed 154.63 MB/s
# [Bản sao của 04.Nâng cao Mina bài 4+5.mp4_2.mp4] copied. Size 60.91 MB. Speed 32.10 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2.mp4] copied. Size 10.95 MB. Speed 4.84 MB/s
# Total files: 4
# Copy at Folder Tài liệu Starting
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.32 MB. Speed 0.19 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.17 MB/s
# [Bản sao của 05. Hội thoại 4.pdf] copied. Size 0.28 MB. Speed 0.13 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.55 MB. Speed 0.30 MB/s
# Copy at Folder Tài liệu Ending
# Copy at Folder Bài 04. Bây giờ là mấy giờ Ending
# Total files: 10
# Copy at Folder Bài 05. Cách đếm ngày tháng năm Starting
# [Bản sao của 01. Từ vựng.mp4_2.mp4] copied. Size 14.42 MB. Speed 8.23 MB/s
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.32 MB. Speed 0.17 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2.mp4] copied. Size 150.99 MB. Speed 106.56 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.15 MB/s
# [Bản sao của 03. Tổng hợp ngữ pháp bài 5.pdf] copied. Size 8.75 MB. Speed 4.21 MB/s
# [Bản sao của 04. Nâng cao Mina - Bài 4+5.mp4_2.mp4] copied. Size 60.91 MB. Speed 27.71 MB/s
# [Bản sao của 05. Hội thoại 5.pdf] copied. Size 0.31 MB. Speed 0.20 MB/s
# [Bản sao của 05. Hội thoại.mp4_2.mp4] copied. Size 12.37 MB. Speed 7.73 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2_2.mp4] copied. Size 14.48 MB. Speed 8.49 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.33 MB. Speed 0.08 MB/s
# Copy at Folder Bài 05. Cách đếm ngày tháng năm Ending
# Total files: 11
# Copy at Folder Bài 06. Cùng nhau ngắm hoa anh đào Starting
# [Bản sao của 01. Từ vựng.mp4_2_2.mp4] copied. Size 14.11 MB. Speed 8.33 MB/s
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.32 MB. Speed 0.12 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2_2.mp4] copied. Size 85.50 MB. Speed 5.53 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.11 MB/s
# [Bản sao của 03. Tổng hợp ngữ pháp bài 6.pdf] copied. Size 7.55 MB. Speed 3.92 MB/s
# [Bản sao của 04. Nâng cao Mina bài 6.mp4_2.mp4] copied. Size 63.82 MB. Speed 35.36 MB/s
# [Bản sao của 05. Hội thoại 6.mp4.mp4] copied. Size 3.11 MB. Speed 1.89 MB/s
# [Bản sao của 05. Hội thoại 6.pdf] copied. Size 0.31 MB. Speed 0.18 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2.mp4] copied. Size 10.98 MB. Speed 7.27 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.33 MB. Speed 0.20 MB/s
# [Bản sao của 07. Đọc hiểu.mp4_2.mp4] copied. Size 46.86 MB. Speed 19.90 MB/s
# Copy at Folder Bài 06. Cùng nhau ngắm hoa anh đào Ending
# Total files: 10
# Copy at Folder Bài 07. Cách cho và nhận Starting
# [Bản sao của 01. Từ vựng.mp4_2.mp4] copied. Size 6.38 MB. Speed 4.13 MB/s
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.32 MB. Speed 0.19 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2.mp4] copied. Size 45.23 MB. Speed 22.41 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.09 MB/s
# [Bản sao của 03. Tổng hợp ngữ pháp bài 7.pdf] copied. Size 1.30 MB. Speed 0.79 MB/s
# [Bản sao của 04.Nâng cao Mina bài 7.mp4_2.mp4] copied. Size 27.26 MB. Speed 14.37 MB/s
# [Bản sao của 05. Hội thoại 7.mp4_2.mp4] copied. Size 3.20 MB. Speed 1.84 MB/s
# [Bản sao của 05. Hội thoại 7.pdf] copied. Size 0.31 MB. Speed 0.20 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.32 MB. Speed 0.19 MB/s
# [Bản sao của 07. Đọc hiểu.mp4_2_2.mp4] copied. Size 18.32 MB. Speed 11.99 MB/s
# Copy at Folder Bài 07. Cách cho và nhận Ending
# Total files: 11
# Copy at Folder Bài 08. Cuộc sống thành phố và nông thôn Starting
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.33 MB. Speed 0.22 MB/s
# [Bản sao của 01.Từ vựng.mp4_2.mp4] copied. Size 10.61 MB. Speed 5.41 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2_2.mp4] copied. Size 47.61 MB. Speed 26.03 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.17 MB/s
# [Bản sao của 03. Tổng hợp ngữ pháp bài 8.pdf] copied. Size 0.86 MB. Speed 0.55 MB/s
# [Bản sao của 04. Nâng cao Mina bài 7 - Xấu vãi- đẹp dã man- - Cách sử dụng は・が.mp4_2.mp4] copied. Size 45.80 MB. Speed 25.87 MB/s
# [Bản sao của 05. Hội thoại 8.mp4_2.mp4] copied. Size 2.99 MB. Speed 1.84 MB/s
# [Bản sao của 05. Hội thoại 8.pdf] copied. Size 0.29 MB. Speed 0.18 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2.mp4] copied. Size 6.69 MB. Speed 4.59 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.32 MB. Speed 0.22 MB/s
# [Bản sao của 07. Đọc hiểu.mp4] copied. Size 14.26 MB. Speed 8.42 MB/s
# Copy at Folder Bài 08. Cuộc sống thành phố và nông thôn Ending
# Total files: 11
# Copy at Folder Bài 09. Tôi yêu Nhật Bản Starting
# [Bản sao của 01. Từ vựng.mp4_2_2.mp4] copied. Size 12.60 MB. Speed 7.86 MB/s
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.32 MB. Speed 0.16 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2_2.mp4] copied. Size 137.11 MB. Speed 83.77 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.17 MB/s
# [Bản sao của 03. Tổng hợp ngữ pháp bài 9.pdf] copied. Size 0.40 MB. Speed 0.21 MB/s
# [Bản sao của 04. Nâng cao Mina 9+10- Cách sử dụng mới của ぜんぜん.mp4_2.mp4] copied. Size 53.05 MB. Speed 28.11 MB/s
# [Bản sao của 05. Hội thoại 9.mp4_2.mp4] copied. Size 13.43 MB. Speed 7.45 MB/s
# [Bản sao của 05. Hội thoại 9.pdf] copied. Size 0.31 MB. Speed 0.17 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2.mp4] copied. Size 13.24 MB. Speed 8.05 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.33 MB. Speed 0.16 MB/s
# [Bản sao của 07. Đọc hiểu.mp4_2.mp4] copied. Size 47.00 MB. Speed 23.73 MB/s
# Copy at Folder Bài 09. Tôi yêu Nhật Bản Ending
# Total files: 11
# Copy at Folder Bài 10. Bảo tàng mỹ thuật Starting
# [Bản sao của 01. Từ vựng.mp4_2.mp4] copied. Size 9.62 MB. Speed 6.39 MB/s
# [Bản sao của 01. Từ vựng.pdf] copied. Size 0.32 MB. Speed 0.18 MB/s
# [Bản sao của 02. Ngữ pháp.mp4_2.mp4] copied. Size 42.32 MB. Speed 26.27 MB/s
# [Bản sao của 02. Ngữ pháp.pdf] copied. Size 0.31 MB. Speed 0.14 MB/s
# [Bản sao của 03. Tổng hợp ngữ phái bài 10.pdf] copied. Size 0.66 MB. Speed 0.40 MB/s
# [Bản sao của 04. Nâng cao Mina bài 10.mp4_2.mp4] copied. Size 17.69 MB. Speed 10.84 MB/s
# [Bản sao của 05. Hội thoại 10.mp4_2.mp4] copied. Size 4.49 MB. Speed 2.69 MB/s
# [Bản sao của 05. Hội thoại 10.pdf] copied. Size 0.32 MB. Speed 0.19 MB/s
# [Bản sao của 06. Nghe hiểu.mp4_2_2.mp4] copied. Size 6.88 MB. Speed 3.09 MB/s
# [Bản sao của 06. Nghe hiểu.pdf] copied. Size 0.33 MB. Speed 0.17 MB/s
# [Bản sao của 07. Đọc hiểu.mp4_2_2.mp4] copied. Size 16.80 MB. Speed 10.34 MB/s
# Copy at Folder Bài 10. Bảo tàng mỹ thuật Ending
# Total files: 7
# Copy at Folder Bài 11. Biểu đồ số lượng học sinh Starting
# [Bản sao của 1 Kanji bài 1.mp4_2.mp4] copied. Size 343.57 MB. Speed 206.08 MB/s
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 13.41 MB. Speed 7.87 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 132.37 MB. Speed 77.78 MB/s
# [Bản sao của 4  Nâng cao Mina 11- -おにいさん は おにです。-.MP4_2.mp4] copied. Size 37.32 MB. Speed 25.61 MB/s
# [Bản sao của 5 Hội thoại.mp4_2.mp4] copied. Size 7.03 MB. Speed 3.88 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2.mp4] copied. Size 11.92 MB. Speed 6.56 MB/s
# [Bản sao của 7 Đọc hiểu.mp4_2.mp4] copied. Size 23.56 MB. Speed 7.47 MB/s
# Copy at Folder Bài 11. Biểu đồ số lượng học sinh Ending
# Total files: 7
# Copy at Folder Bài 12. Du lịch đảo okinawa Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 54.36 MB. Speed 31.34 MB/s
# [Bản sao của 2  Từ vựng.mp4_2.mp4] copied. Size 6.40 MB. Speed 4.29 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2_2.mp4] copied. Size 40.17 MB. Speed 23.62 MB/s
# [Bản sao của 4 Nâng cao Mina bài 12.MP4_2.mp4] copied. Size 12.65 MB. Speed 6.02 MB/s
# [Bản sao của 5 Hội thoại.mp4_2_2.mp4] copied. Size 4.17 MB. Speed 2.68 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2_2.mp4] copied. Size 8.99 MB. Speed 5.39 MB/s
# [Bản sao của 7 Đọc hiểu.mp4] copied. Size 16.91 MB. Speed 9.22 MB/s
# Copy at Folder Bài 12. Du lịch đảo okinawa Ending
# Total files: 7
# Copy at Folder Bài 13. Giấc mơ trúng sổ số của tôi Starting
# [Bản sao của 1 Kanji.mp4_2_2.mp4] copied. Size 149.67 MB. Speed 95.38 MB/s
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 13.30 MB. Speed 8.32 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 178.03 MB. Speed 104.72 MB/s
# [Bản sao của 4  Nâng cao Mina bài 13.MP4_2.mp4] copied. Size 56.06 MB. Speed 35.85 MB/s
# [Bản sao của 5  Hội thoại.mp4_2.mp4] copied. Size 11.12 MB. Speed 5.41 MB/s
# [Bản sao của 6 Nghe hiểu.mp4] copied. Size 18.49 MB. Speed 10.63 MB/s
# [Bản sao của 7  Đọc hiểu.mp4] copied. Size 33.85 MB. Speed 19.37 MB/s
# Copy at Folder Bài 13. Giấc mơ trúng sổ số của tôi Ending
# Total files: 5
# Copy at Folder Bài 14. Bức thư bằng hình ảnh của tôi Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 180.89 MB. Speed 119.54 MB/s
# [Bản sao của 3 Ngữ pháp 1.mp4_2.mp4] copied. Size 71.11 MB. Speed 41.63 MB/s
# [Bản sao của 4 Ngữ pháp 2.mp4_2.mp4] exists.
# [Bản sao của 5 Nâng cao Mina bài 14+15.MP4_2.mp4] copied. Size 75.12 MB. Speed 51.41 MB/s
# [Bản sao của 8 Đọc hiểu.mp4_2.mp4] copied. Size 51.03 MB. Speed 30.77 MB/s
# Copy at Folder Bài 14. Bức thư bằng hình ảnh của tôi Ending
# Total files: 6
# Copy at Folder Bài 15. Thời gian cố gắng để thành công Starting
# [Bản sao của 1 Kanji.mp4_2_2.mp4] copied. Size 208.83 MB. Speed 126.64 MB/s
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 9.47 MB. Speed 4.08 MB/s
# [Bản sao của 3  Ngữ pháp.mp4_2.mp4] copied. Size 76.54 MB. Speed 48.50 MB/s
# [Bản sao của 4 Hội thoại.mp4_2.mp4] copied. Size 13.09 MB. Speed 8.71 MB/s
# [Bản sao của 5 Nghe hiểu.mp4_2.mp4] copied. Size 12.99 MB. Speed 2.73 MB/s
# [Bản sao của 6 Đọc hiểu.mp4_2.mp4] copied. Size 49.11 MB. Speed 24.10 MB/s
# Copy at Folder Bài 15. Thời gian cố gắng để thành công Ending
# Total files: 7
# Copy at Folder Bài 16. Động vật trong tưởng tượng Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 406.34 MB. Speed 247.64 MB/s
# [Bản sao của 2 Từ vựng.mp4_2_2.mp4] copied. Size 23.45 MB. Speed 13.12 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 102.56 MB. Speed 62.05 MB/s
# [Bản sao của 4 Nâng cao Mina bài 16.MP4_2.mp4] copied. Size 36.25 MB. Speed 18.71 MB/s
# [Bản sao của 5  Hội thoại.mp4_2.mp4] copied. Size 11.95 MB. Speed 6.84 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2.mp4] copied. Size 13.61 MB. Speed 8.21 MB/s
# [Bản sao của 7 Đọc hiểu.mp4_2.mp4] copied. Size 40.90 MB. Speed 24.02 MB/s
# Copy at Folder Bài 16. Động vật trong tưởng tượng Ending
# Total files: 7
# Copy at Folder Bài 17. Những quy tắc thời edo Starting
# [Bản sao của 1 Kanji.mp4] copied. Size 70.09 MB. Speed 38.18 MB/s
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 5.97 MB. Speed 2.31 MB/s
# [Bản sao của 3 Ngữ Pháp.mp4_2_2.mp4] copied. Size 37.77 MB. Speed 17.25 MB/s
# [Bản sao của 4 Nâng cao Mina bài 17.MP4_2.mp4] copied. Size 19.34 MB. Speed 10.78 MB/s
# [Bản sao của 5 Hội thoại.mp4_2.mp4] copied. Size 4.05 MB. Speed 1.76 MB/s
# [Bản sao của 6  Nghe hiểu.mp4_2.mp4] copied. Size 8.29 MB. Speed 6.11 MB/s
# [Bản sao của 7 Đọc hiểu.mp4_2_2.mp4] copied. Size 15.44 MB. Speed 7.51 MB/s
# Copy at Folder Bài 17. Những quy tắc thời edo Ending
# Total files: 6
# Copy at Folder Bài 18. Du lịch theo nhóm và cá nhân Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 129.51 MB. Speed 66.84 MB/s
# [Bản sao của 2 Từ vựng.mp4_2_2.mp4] copied. Size 9.43 MB. Speed 5.00 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 103.92 MB. Speed 60.74 MB/s
# [Bản sao của 4  Nâng cao Mina bài 18.MP4_2.mp4] copied. Size 63.45 MB. Speed 40.70 MB/s
# [Bản sao của 5 Hội thoại.mp4_2_2.mp4] copied. Size 18.26 MB. Speed 6.98 MB/s
# [Bản sao của 6  Nghe hiểu.mp4] copied. Size 18.07 MB. Speed 13.81 MB/s
# Copy at Folder Bài 18. Du lịch theo nhóm và cá nhân Ending
# Total files: 6
# Copy at Folder Bài 19. Môn đấu vật sumo Starting
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 4.57 MB. Speed 2.59 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2_2.mp4] copied. Size 30.20 MB. Speed 21.21 MB/s
# [Bản sao của 4 Nâng cao Mina bài 19.MP4_2.mp4] copied. Size 13.32 MB. Speed 7.98 MB/s
# [Bản sao của 5 Hội thoại.mp4_2.mp4] copied. Size 4.53 MB. Speed 2.75 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2.mp4] copied. Size 6.03 MB. Speed 3.19 MB/s
# [Bản sao của 7 Đọc hiểu.mp4_2.mp4] copied. Size 46.00 MB. Speed 22.95 MB/s
# Copy at Folder Bài 19. Môn đấu vật sumo Ending
# Total files: 7
# Copy at Folder Bài 20. Cuộc đời của nhà tiểu thuyết Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 232.54 MB. Speed 137.61 MB/s
# [Bản sao của 2 Từ vựng.mp4_2_2.mp4] copied. Size 7.83 MB. Speed 3.51 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 118.81 MB. Speed 64.22 MB/s
# [Bản sao của 4 Nâng cao Mina bài 20.MP4_2.mp4] copied. Size 297.46 MB. Speed 167.95 MB/s
# [Bản sao của 5 Hội Thoại.mp4_2_2.mp4] copied. Size 6.52 MB. Speed 4.40 MB/s
# [Bản sao của 6  Nghe hiểu.mp4_2.mp4] copied. Size 11.73 MB. Speed 5.54 MB/s
# [Bản sao của 7 Đọc hiểu.mp4] copied. Size 31.05 MB. Speed 21.15 MB/s
# Copy at Folder Bài 20. Cuộc đời của nhà tiểu thuyết Ending
# Total files: 6
# Copy at Folder Bài 21. Tôi cũng nghĩ thế! Starting
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 10.81 MB. Speed 8.24 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2_2.mp4] copied. Size 70.51 MB. Speed 41.46 MB/s
# [Bản sao của 4 Nâng cao Mina bài 21.MP4_2.mp4] copied. Size 46.11 MB. Speed 24.50 MB/s
# [Bản sao của 5 Hội thoại.mp4_2.mp4] copied. Size 20.30 MB. Speed 13.01 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2.mp4] copied. Size 11.39 MB. Speed 6.29 MB/s
# [Bản sao của 7 Đọc hiểu.mp4_2.mp4] copied. Size 47.99 MB. Speed 32.73 MB/s
# Copy at Folder Bài 21. Tôi cũng nghĩ thế! Ending
# Total files: 6
# Copy at Folder Bài 22. Phát sóng truyền hình Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 66.54 MB. Speed 41.10 MB/s
# [Bản sao của 2 Từ vựng.mp4_2_2.mp4] copied. Size 4.61 MB. Speed 2.61 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 33.37 MB. Speed 18.14 MB/s
# [Bản sao của 5 Hội thoại.mp4_2_2.mp4] copied. Size 7.19 MB. Speed 4.30 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2_2.mp4] copied. Size 7.53 MB. Speed 4.87 MB/s
# [Bản sao của 7 Đọc hiểu.mp4_2_2.mp4] copied. Size 17.36 MB. Speed 7.11 MB/s
# Copy at Folder Bài 22. Phát sóng truyền hình Ending
# Total files: 6
# Copy at Folder Bài 23. Cảm giác khi uống cafe Starting
# [Bản sao của 1 Kanji.mp4_2_2.mp4] copied. Size 66.03 MB. Speed 40.53 MB/s
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 5.60 MB. Speed 2.92 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2_2.mp4] copied. Size 18.07 MB. Speed 13.04 MB/s
# [Bản sao của 5 Hội thoại.mp4_2.mp4] copied. Size 9.53 MB. Speed 5.29 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2.mp4] copied. Size 8.53 MB. Speed 5.33 MB/s
# [Bản sao của 7 Đọc hiểu.mp4] copied. Size 13.82 MB. Speed 8.72 MB/s
# Copy at Folder Bài 23. Cảm giác khi uống cafe Ending
# Total files: 6
# Copy at Folder Bài 24. Làm ơn hãy nói tiếng Nhật Starting
# [Bản sao của 2 Từ vựng.mp4_2_2.mp4] copied. Size 8.25 MB. Speed 3.99 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2.mp4] copied. Size 54.24 MB. Speed 26.96 MB/s
# [Bản sao của 4 Nâng cao Mina bài 24.MP4_2.mp4] copied. Size 94.32 MB. Speed 50.33 MB/s
# [Bản sao của 5 Hội thoại.mp4_2_2.mp4] copied. Size 30.08 MB. Speed 18.56 MB/s
# [Bản sao của 6 Nghe hiểu.mp4_2_2.mp4] copied. Size 12.28 MB. Speed 6.58 MB/s
# [Bản sao của 7 Đọc hiểu.mp4] copied. Size 41.09 MB. Speed 23.54 MB/s
# Copy at Folder Bài 24. Làm ơn hãy nói tiếng Nhật Ending
# Total files: 7
# Copy at Folder Bài 25. Tương lai thì sẽ như thế nào Starting
# [Bản sao của 1 Kanji.mp4_2.mp4] copied. Size 164.38 MB. Speed 82.23 MB/s
# [Bản sao của 2 Từ vựng.mp4_2.mp4] copied. Size 6.88 MB. Speed 3.76 MB/s
# [Bản sao của 3 Ngữ pháp.mp4_2_2.mp4] copied. Size 54.35 MB. Speed 35.58 MB/s
# [Bản sao của 4 Nâng cao Mina bài 25.MP4_2.mp4] copied. Size 94.32 MB. Speed 56.61 MB/s
# [Bản sao của 5  Hội thoại.mp4_2.mp4] copied. Size 41.53 MB. Speed 21.82 MB/s
# [Bản sao của 6 Nghe hiểu.mp4] copied. Size 17.19 MB. Speed 8.84 MB/s
# [Bản sao của 7   Đọc hiểu.mp4] copied. Size 48.28 MB. Speed 27.13 MB/s
# Copy at Folder Bài 25. Tương lai thì sẽ như thế nào Ending
# Copy at Folder Bài giảng Ending
# [N5.pdf] copied. Size 0.49 MB. Speed 0.21 MB/s
# Total files: 4
# Copy at Folder Đề thi Starting
# Total files: 6
# Copy at Folder Luyện nghe hiểu Starting
# Total files: 12
# Copy at Folder Mondai 1 Starting
# [Bản sao của 02 Track 2.mp3] copied. Size 0.29 MB. Speed 0.09 MB/s
# [Bản sao của 03 Track 3.mp3] copied. Size 0.25 MB. Speed 0.14 MB/s
# [Bản sao của 04 Track 4.mp3] copied. Size 0.66 MB. Speed 0.36 MB/s
# [Bản sao của 05 Track 5.mp3] copied. Size 0.83 MB. Speed 0.48 MB/s
# [Bản sao của 06 Track 6.mp3] copied. Size 0.88 MB. Speed 0.51 MB/s
# [Bản sao của 07 Track 7.mp3] copied. Size 0.75 MB. Speed 0.44 MB/s
# [Bản sao của 08 Track 8.mp3] copied. Size 0.47 MB. Speed 0.33 MB/s
# [Bản sao của 09 Track 9.mp3] copied. Size 0.46 MB. Speed 0.28 MB/s
# [Bản sao của 10 Track 10.mp3] copied. Size 0.67 MB. Speed 0.46 MB/s
# [Bản sao của 11 Track 11.mp3] copied. Size 0.65 MB. Speed 0.39 MB/s
# [Bản sao của 24 Track 24.mp3] copied. Size 0.92 MB. Speed 0.55 MB/s
# [Bản sao của 25 Track 25.mp3] copied. Size 0.93 MB. Speed 0.27 MB/s
# Copy at Folder Mondai 1 Ending
# Total files: 3
# Copy at Folder Mondai 2 Starting
# [Bản sao của 15 Track 15.mp3] copied. Size 0.93 MB. Speed 0.56 MB/s
# [Bản sao của 16 Track 16.mp3] copied. Size 0.98 MB. Speed 0.61 MB/s
# [Bản sao của 22 Track 22.mp3] copied. Size 0.85 MB. Speed 0.19 MB/s
# Copy at Folder Mondai 2 Ending
# Total files: 1
# Copy at Folder Mondai 3 Starting
# [Bản sao của 01 Dungmori - Khóa học N5 _ Mondai 3.pdf] copied. Size 0.57 MB. Speed 0.42 MB/s
# Copy at Folder Mondai 3 Ending
# Total files: 10
# Copy at Folder Mondai 4 Starting
# [Bản sao của 39 Track 39.mp3] copied. Size 0.63 MB. Speed 0.45 MB/s
# [Bản sao của 40 Track 40.mp3] copied. Size 0.69 MB. Speed 0.50 MB/s
# [Bản sao của 41 Track 41.mp3] copied. Size 0.57 MB. Speed 0.18 MB/s
# [Bản sao của 42 Track 42.mp3] copied. Size 0.60 MB. Speed 0.46 MB/s
# [Bản sao của 43 Track 43.mp3] copied. Size 0.68 MB. Speed 0.50 MB/s
# [Bản sao của 44 Track 44.mp3] copied. Size 0.64 MB. Speed 0.40 MB/s
# [Bản sao của 45 Track 45.mp3] copied. Size 0.63 MB. Speed 0.33 MB/s
# [Bản sao của 46 Track 46.mp3] copied. Size 0.55 MB. Speed 0.34 MB/s
# [Bản sao của 47 Track 47.mp3] copied. Size 0.58 MB. Speed 0.34 MB/s
# [Bản sao của 48 Track 48.mp3] copied. Size 0.64 MB. Speed 0.37 MB/s
# Copy at Folder Mondai 4 Ending
# Total files: 13
# Copy at Folder Đề thi thử số 1 Starting
# [Bản sao của 23 Track 23.mp3] copied. Size 0.58 MB. Speed 0.27 MB/s
# [Bản sao của 24 Track 24.mp3] copied. Size 0.55 MB. Speed 0.34 MB/s
# [Bản sao của 25 Track 25.mp3] copied. Size 0.62 MB. Speed 0.34 MB/s
# [Bản sao của 26 Track 26.mp3] copied. Size 0.63 MB. Speed 0.33 MB/s
# [Bản sao của 27 Track 27.mp3] copied. Size 0.69 MB. Speed 0.42 MB/s
# [Bản sao của 30 Track 30.mp3] copied. Size 0.53 MB. Speed 0.20 MB/s
# [Bản sao của 31 Track 31.mp3] copied. Size 0.41 MB. Speed 0.21 MB/s
# [Bản sao của 32 Track 32.mp3] copied. Size 0.51 MB. Speed 0.34 MB/s
# [Bản sao của 33 Track 33.mp3] copied. Size 0.45 MB. Speed 0.26 MB/s
# [Bản sao của 34 Track 34.mp3] copied. Size 0.48 MB. Speed 0.28 MB/s
# [Bản sao của 35 Track 35.mp3] copied. Size 0.43 MB. Speed 0.23 MB/s
# [Bản sao của Track 1.mp3] copied. Size 0.78 MB. Speed 0.48 MB/s
# [Bản sao của Track 2.mp3] copied. Size 0.85 MB. Speed 0.42 MB/s
# Copy at Folder Đề thi thử số 1 Ending
# Total files: 13
# Copy at Folder Đề thi thử số 2 Starting
# [Bản sao của 43 Track 43.mp3] copied. Size 0.99 MB. Speed 0.59 MB/s
# [Bản sao của 45 Track 45.mp3] copied. Size 0.98 MB. Speed 0.37 MB/s
# [Bản sao của 57 Track 57.mp3] copied. Size 0.83 MB. Speed 0.48 MB/s
# [Bản sao của 58 Track 58.mp3] copied. Size 0.70 MB. Speed 0.51 MB/s
# [Bản sao của 59 Track 59.mp3] copied. Size 0.64 MB. Speed 0.40 MB/s
# [Bản sao của 60 Track 60.mp3] copied. Size 0.60 MB. Speed 0.39 MB/s
# [Bản sao của 61 Track 61.mp3] copied. Size 0.80 MB. Speed 0.51 MB/s
# [Bản sao của 64 Track 64.mp3] copied. Size 0.50 MB. Speed 0.35 MB/s
# [Bản sao của 65 Track 65.mp3] copied. Size 0.46 MB. Speed 0.26 MB/s
# [Bản sao của 66 Track 66.mp3] copied. Size 0.45 MB. Speed 0.27 MB/s
# [Bản sao của 67 Track 67.mp3] copied. Size 0.44 MB. Speed 0.16 MB/s
# [Bản sao của 68 Track 68.mp3] copied. Size 0.47 MB. Speed 0.21 MB/s
# [Bản sao của 69 Track 69.mp3] copied. Size 0.52 MB. Speed 0.30 MB/s
# Copy at Folder Đề thi thử số 2 Ending
# Copy at Folder Luyện nghe hiểu Ending
# Total files: 5
# Copy at Folder Thi thử JLPT 1 Starting
# Total files: 24
# Copy at Folder Bài nghe Starting
# [Bản sao của 03.mp3] copied. Size 0.50 MB. Speed 0.30 MB/s
# [Bản sao của 04.mp3] copied. Size 0.56 MB. Speed 0.33 MB/s
# [Bản sao của 05.mp3] copied. Size 0.53 MB. Speed 0.29 MB/s
# [Bản sao của 06.mp3] copied. Size 0.50 MB. Speed 0.35 MB/s
# [Bản sao của 07.mp3] copied. Size 0.50 MB. Speed 0.33 MB/s
# [Bản sao của 08.mp3] copied. Size 0.55 MB. Speed 0.32 MB/s
# [Bản sao của 09.mp3] copied. Size 0.56 MB. Speed 0.30 MB/s
# [Bản sao của 11.mp3] copied. Size 0.77 MB. Speed 0.35 MB/s
# [Bản sao của 12.mp3] copied. Size 0.66 MB. Speed 0.38 MB/s
# [Bản sao của 13.mp3] copied. Size 0.66 MB. Speed 0.37 MB/s
# [Bản sao của 14.mp3] copied. Size 0.70 MB. Speed 0.42 MB/s
# [Bản sao của 15.mp3] copied. Size 0.60 MB. Speed 0.42 MB/s
# [Bản sao của 16.mp3] copied. Size 0.72 MB. Speed 0.17 MB/s
# [Bản sao của 18.mp3] copied. Size 0.31 MB. Speed 0.18 MB/s
# [Bản sao của 19.mp3] copied. Size 0.30 MB. Speed 0.21 MB/s
# [Bản sao của 20.mp3] copied. Size 0.32 MB. Speed 0.20 MB/s
# [Bản sao của 21.mp3] copied. Size 0.36 MB. Speed 0.19 MB/s
# [Bản sao của 22.mp3] copied. Size 0.35 MB. Speed 0.20 MB/s
# [Bản sao của 24.mp3] copied. Size 0.26 MB. Speed 0.15 MB/s
# [Bản sao của 25.mp3] copied. Size 0.28 MB. Speed 0.13 MB/s
# [Bản sao của 26.mp3] copied. Size 0.25 MB. Speed 0.17 MB/s
# [Bản sao của 27.mp3] copied. Size 0.27 MB. Speed 0.17 MB/s
# [Bản sao của 28.mp3] copied. Size 0.26 MB. Speed 0.19 MB/s
# [Bản sao của 29.mp3] copied. Size 0.25 MB. Speed 0.16 MB/s
# Copy at Folder Bài nghe Ending
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Nghe hiểu.pdf] copied. Size 1.48 MB. Speed 0.83 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Từ vựng - Chữ hán.pdf] copied. Size 0.74 MB. Speed 0.47 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Đọc Hiểu - Đáp án.pdf] copied. Size 0.76 MB. Speed 0.51 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Đọc Hiểu.pdf] exists.
# Copy at Folder Thi thử JLPT 1 Ending
# Total files: 6
# Copy at Folder Thi thử JLPT 2 Starting
# Total files: 22
# Copy at Folder Bài nghe Starting
# [Bản sao của 57 Track 57.mp3] copied. Size 0.92 MB. Speed 0.64 MB/s
# [Bản sao của 58 Track 58.mp3] copied. Size 0.82 MB. Speed 0.58 MB/s
# [Bản sao của 59 Track 59.mp3] copied. Size 0.76 MB. Speed 0.41 MB/s
# [Bản sao của 60 Track 60 (1).mp3] copied. Size 0.69 MB. Speed 0.23 MB/s
# [Bản sao của 60 Track 60.mp3] exists.
# [Bản sao của 61 Track 61.mp3] copied. Size 0.82 MB. Speed 0.50 MB/s
# [Bản sao của 62 Track 62.mp3] copied. Size 0.90 MB. Speed 0.53 MB/s
# [Bản sao của 64 Track 64.mp3] copied. Size 0.78 MB. Speed 0.42 MB/s
# [Bản sao của 65 Track 65.mp3] copied. Size 0.78 MB. Speed 0.33 MB/s
# [Bản sao của 66 Track 66.mp3] copied. Size 0.87 MB. Speed 0.49 MB/s
# [Bản sao của 67 Track 67.mp3] copied. Size 0.69 MB. Speed 0.48 MB/s
# [Bản sao của 69 Track 69.mp3] copied. Size 0.98 MB. Speed 0.57 MB/s
# [Bản sao của 70 Track 70.mp3] copied. Size 0.64 MB. Speed 0.43 MB/s
# [Bản sao của 71 Track 71.mp3] copied. Size 0.60 MB. Speed 0.35 MB/s
# [Bản sao của 72 Track 72.mp3] copied. Size 0.61 MB. Speed 0.42 MB/s
# [Bản sao của 73 Track 73.mp3] copied. Size 0.61 MB. Speed 0.33 MB/s
# [Bản sao của 74 Track 74.mp3] copied. Size 0.89 MB. Speed 0.59 MB/s
# [Bản sao của 75 Track 75.mp3] copied. Size 0.57 MB. Speed 0.38 MB/s
# [Bản sao của 76 Track 76.mp3] copied. Size 0.55 MB. Speed 0.38 MB/s
# [Bản sao của 77 Track 77.mp3] copied. Size 0.52 MB. Speed 0.28 MB/s
# [Bản sao của 78 Track 78.mp3] copied. Size 0.55 MB. Speed 0.27 MB/s
# [Bản sao của 79 Track 79.mp3] copied. Size 0.64 MB. Speed 0.42 MB/s
# Copy at Folder Bài nghe Ending
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Nghe hiểu.pdf] copied. Size 1.17 MB. Speed 0.57 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Từ vựng - Chữ hán - Đáp án.pdf] copied. Size 0.83 MB. Speed 0.36 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Từ vựng - Chữ hán.pdf] exists.
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Đọc Hiểu- đáp án.pdf] copied. Size 0.81 MB. Speed 0.54 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài thi_ Đọc Hiểu.pdf] exists.
# Copy at Folder Thi thử JLPT 2 Ending
# Total files: 4
# Copy at Folder Thi thử JLPT 3 Starting
# Total files: 22
# Copy at Folder Bài nghe Starting
# [Bản sao của 02 Nummer 2.mp3] copied. Size 0.61 MB. Speed 0.35 MB/s
# [Bản sao của 04 Nummer 4.mp3] copied. Size 0.87 MB. Speed 0.60 MB/s
# [Bản sao của 08 Nummer 8.mp3] copied. Size 0.96 MB. Speed 0.28 MB/s
# [Bản sao của 09 Nummer 9.mp3] copied. Size 0.83 MB. Speed 0.52 MB/s
# [Bản sao của 11 Nummer 11.mp3] copied. Size 0.61 MB. Speed 0.36 MB/s
# [Bản sao của 13 Nummer 13.mp3] copied. Size 0.93 MB. Speed 0.43 MB/s
# [Bản sao của 15 Nummer 15.mp3] copied. Size 0.98 MB. Speed 0.58 MB/s
# [Bản sao của 20 Nummer 20.mp3] copied. Size 0.58 MB. Speed 0.39 MB/s
# [Bản sao của 21 Nummer 21.mp3] copied. Size 0.87 MB. Speed 0.48 MB/s
# [Bản sao của 22 Nummer 22.mp3] copied. Size 0.48 MB. Speed 0.28 MB/s
# [Bản sao của 23 Nummer 23.mp3] copied. Size 0.49 MB. Speed 0.29 MB/s
# [Bản sao của 24 Nummer 24.mp3] copied. Size 0.56 MB. Speed 0.32 MB/s
# [Bản sao của 25 Nummer 25.mp3] copied. Size 0.60 MB. Speed 0.32 MB/s
# [Bản sao của 26 Nummer 26.mp3] copied. Size 0.54 MB. Speed 0.31 MB/s
# [Bản sao của 27 Nummer 27.mp3] copied. Size 0.49 MB. Speed 0.31 MB/s
# [Bản sao của 28 Nummer 28.mp3] copied. Size 0.81 MB. Speed 0.43 MB/s
# [Bản sao của 29 Nummer 29.mp3] copied. Size 0.48 MB. Speed 0.27 MB/s
# [Bản sao của 30 Nummer 30.mp3] copied. Size 0.46 MB. Speed 0.26 MB/s
# [Bản sao của 31 Nummer 31.mp3] copied. Size 0.48 MB. Speed 0.29 MB/s
# [Bản sao của 32 Nummer 32.mp3] copied. Size 0.47 MB. Speed 0.30 MB/s
# [Bản sao của 33 Nummer 33.mp3] copied. Size 0.48 MB. Speed 0.29 MB/s
# [Bản sao của 34 Nummer 34.mp3] copied. Size 0.47 MB. Speed 0.27 MB/s
# Copy at Folder Bài nghe Ending
# [Bản sao của Dungmori - Khóa học N5 _ Bài Thi _ Từ Vựng - Chữ Hán.pdf] copied. Size 1.05 MB. Speed 0.52 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài Thi_ Nghe Hiểu.pdf] copied. Size 1.25 MB. Speed 0.70 MB/s
# [Bản sao của Dungmori - Khóa học N5 _ Bài Thi_ Đọc Hiểu.pdf] copied. Size 0.69 MB. Speed 0.41 MB/s
# Copy at Folder Thi thử JLPT 3 Ending
# Copy at Folder Đề thi Ending
# Done. Total Size 8.26 GB. Total Time 1032 s. SpeedMB 8.19 MB/s
